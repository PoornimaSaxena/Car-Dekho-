# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Cardekho.csv')

# %%
data.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
data.shape
# Out:
# (15411, 14)

# %%
#Summary Statistics for the data 

data.describe()
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean    9811.857699      6.036338  5.561648e+04     19.701151   1486.057751
# std     5643.418542      3.013291  5.161855e+04      4.171265    521.106696
# min        0.000000      0.000000  1.000000e+02      4.000000    793.000000
# 25%     4906.500000      4.000000  3.000000e+04     17.000000   1197.000000
# 50%     9872.000000      6.000000  5.000000e+04     19.670000   1248.000000
# 75%    14668.500000      8.000000  7.000000e+04     22.700000   1582.000000
# max    19543.000000     29.000000  3.800000e+06     33.540000   6592.000000
#
#           max_power         seats  selling_price
# count  15411.000000  15411.000000   1.541100e+04
# mean     100.588254      5.325482   7.749711e+05
# std       42.972979      0.807628   8.941284e+05
# min       38.400000      0.000000   4.000000e+04
# ...

# %%
'''Check whether our data is clean or not

Null values 
Duplicates 
Wrong data
'''
# Out:
# 'Check whether our data is clean or not\n\nNull values \nDuplicates \nWrong data\n'

# %%
data['car_name'].unique()
# Out:
# array(['Maruti Alto', 'Hyundai Grand', 'Hyundai i20', 'Ford Ecosport',
#        'Maruti Wagon R', 'Hyundai i10', 'Hyundai Venue', 'Maruti Swift',
#        'Hyundai Verna', 'Renault Duster', 'Mini Cooper', 'Maruti Ciaz',
#        'Mercedes-Benz C-Class', 'Toyota Innova', 'Maruti Baleno',
#        'Maruti Swift Dzire', 'Volkswagen Vento', 'Hyundai Creta',
#        'Honda City', 'Mahindra Bolero', 'Toyota Fortuner', 'Renault KWID',
#        'Honda Amaze', 'Hyundai Santro', 'Mahindra XUV500',
#        'Mahindra KUV100', 'Maruti Ignis', 'Datsun RediGO',
#        'Mahindra Scorpio', 'Mahindra Marazzo', 'Ford Aspire', 'Ford Figo',
#        'Maruti Vitara', 'Tata Tiago', 'Volkswagen Polo', 'Kia Seltos',
#        'Maruti Celerio', 'Datsun GO', 'BMW 5', 'Honda CR-V',
#        'Ford Endeavour', 'Mahindra KUV', 'Honda Jazz', 'BMW 3', 'Audi A4',
#        'Tata Tigor', 'Maruti Ertiga', 'Tata Safari', 'Mahindra Thar',
#        'Tata Hexa', 'Land Rover Rover', 'Maruti Eeco', 'Audi A6',
# ...

# %%
data['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
data['car_name'].nunique()
# Out:
# 121

# %%
#which car is being sold on the platform

data['car_name'].value_counts()
# Out:
# car_name
# Hyundai i20              906
# Maruti Swift Dzire       890
# Maruti Swift             781
# Maruti Alto              778
# Honda City               757
#                         ...
# Mercedes-AMG C             1
# Rolls-Royce Ghost          1
# Maserati Quattroporte      1
# Isuzu MUX                  1
# Force Gurkha               1
# Name: count, Length: 121, dtype: int64

# %% [raw]
#  EXPLORATORY DATA ANALYSIS
#
#
# 1. Univariate Analysis

# %%
sns.kdeplot(x = data['selling_price'], shade = True)
# Out:
# C:\Users\Poornima\AppData\Local\Temp\ipykernel_19348\521446184.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = data['selling_price'], shade = True)
# <Axes: xlabel='selling_price', ylabel='Density'>

# %%
sns.kdeplot(x = data['mileage'], shade = True)
# Out:
# C:\Users\Poornima\AppData\Local\Temp\ipykernel_19348\368844232.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = data['mileage'], shade = True)
# <Axes: xlabel='mileage', ylabel='Density'>

# %%
sns.kdeplot(x = data['seats'], shade = True)
# Out:
# C:\Users\Poornima\AppData\Local\Temp\ipykernel_19348\1386095162.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = data['seats'], shade = True)
# <Axes: xlabel='seats', ylabel='Density'>

# %%
sns.kdeplot(x = data['vehicle_age'], shade = True)
# Out:
# C:\Users\Poornima\AppData\Local\Temp\ipykernel_19348\2816587630.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = data['vehicle_age'], shade = True)
# <Axes: xlabel='vehicle_age', ylabel='Density'>

# %% [raw]
# # 2. Bivariate Analysis - Two find the correlation between two variable.

# %%
sns.scatterplot (data = data, x ='vehicle_age' , y ='selling_price')
# Out:
# <Axes: xlabel='vehicle_age', ylabel='selling_price'>

# %%
sns.scatterplot (data = data, x ='mileage' , y ='selling_price')
# Out:
# <Axes: xlabel='mileage', ylabel='selling_price'>

# %%
data[data['mileage'] >=  30]
# Out:
#        Unnamed: 0        car_name   brand    model  vehicle_age  km_driven  \
# 169           224  Maruti Wagon R  Maruti  Wagon R            3      52000
# 182           239  Maruti Wagon R  Maruti  Wagon R            8      64000
# 317           404  Maruti Celerio  Maruti  Celerio            3      28000
# 422           544     Maruti Alto  Maruti     Alto            5      45000
# 480           618     Maruti Alto  Maruti     Alto            5      42000
# ...           ...             ...     ...      ...          ...        ...
# 14932       18941  Maruti Celerio  Maruti  Celerio            2      50000
# 15016       19039     Maruti Alto  Maruti     Alto            5      78950
# 15226       19306  Maruti Wagon R  Maruti  Wagon R            5      74844
# 15317       19425  Maruti Wagon R  Maruti  Wagon R            7      83521
# 15398       19528     Maruti Alto  Maruti     Alto            7      44000
#
# ...

# %%
data[data['mileage'] <=  30]
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
sns.scatterplot (data = data, x ='max_power' , y ='selling_price')
# Out:
# <Axes: xlabel='max_power', ylabel='selling_price'>

# %%
# 3. Multivariate Analysis

# %%
numerical_variables =[variables for variables in data.columns if data[variables].dtype != '0']
numerical_variables
# Out:
# ['Unnamed: 0',
#  'car_name',
#  'brand',
#  'model',
#  'vehicle_age',
#  'km_driven',
#  'seller_type',
#  'fuel_type',
#  'transmission_type',
#  'mileage',
#  'engine',
#  'max_power',
#  'seats',
#  'selling_price']

# %%
# Calculate the correlation matrix for selected numerical features
correlation_matrix = data[numerical_variable].corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                vehicle_age  km_driven   mileage    engine  max_power  \
# vehicle_age       1.000000   0.333891 -0.257394  0.098965   0.005208
# km_driven         0.333891   1.000000 -0.105239  0.192885   0.044421
# mileage          -0.257394  -0.105239  1.000000 -0.632987  -0.533128
# engine            0.098965   0.192885 -0.632987  1.000000   0.807368
# max_power         0.005208   0.044421 -0.533128  0.807368   1.000000
# seats             0.030791   0.192830 -0.440280  0.551236   0.172257
# selling_price    -0.241851  -0.080030 -0.305549  0.585844   0.750236
#
#                   seats  selling_price
# vehicle_age    0.030791      -0.241851
# km_driven      0.192830      -0.080030
# mileage       -0.440280      -0.305549
# engine         0.551236       0.585844
# max_power      0.172257       0.750236
# seats          1.000000       0.115033
# selling_price  0.115033       1.000000

# %%
sns.heatmap(data = data[numerical_variable].corr() , annot = True , cmap = "plasma", linewidth = 1)
# Out:
# <Axes: >

# %%
# Insights from this

# max power and engine are highly correlated.
# Max power engine impact selling price positively.

# %% [raw]
# Feature Enginnering
#
# we remove unnecessary columns from the dataset.

# %%
data.drop(labels = ["car_name" , "brand" , "model" , "seller_type"], axis = 1 , inplace = True)

data
# Out:
#        Unnamed: 0  vehicle_age  km_driven fuel_type transmission_type  \
# 0               0            9     120000    Petrol            Manual
# 1               1            5      20000    Petrol            Manual
# 2               2           11      60000    Petrol            Manual
# 3               3            9      37000    Petrol            Manual
# 4               4            6      30000    Diesel            Manual
# ...           ...          ...        ...       ...               ...
# 15406       19537            9      10723    Petrol            Manual
# 15407       19540            2      18000    Petrol            Manual
# 15408       19541            6      67000    Diesel            Manual
# 15409       19542            5    3800000    Diesel            Manual
# 15410       19543            2      13000    Petrol         Automatic
#
#        mileage  engine  max_power  seats  selling_price
# 0        19.70     796      46.30      5         120000
# ...
